# %% [markdown]
# # Machine Learning Final Project
# SVM/SVR for Credircard Usage Prediction - 7 Features

# %% [markdown]
# ### The Required Packages Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.svm import SVC
from sklearn.svm import SVR
from sklearn.svm import LinearSVC
from sklearn import metrics
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.datasets import make_moons
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# %% [markdown]
# ### Loading Data

# %%
dta = pd.read_csv(r"C:\Users\kenne\桌面\機器學習\Final Project\BankCreditcardDataSVM.csv")
# print(dta)
crdt = pd.DataFrame(dta)
# print(crdt)
X = crdt[['Customer_Age', 'Customer_Gender', 'Education_D1_Doctorate', 
          'Education_D2_PostGraduate', 'Education_D3_Graduate', 
          'Education_D4_College', 'Education_D5_HighSchool', 
          'Education_D6_Uneducated', 'Marital_D1_Single', 
          'Marital_D2_Married', 'Marital_D3_Divorced', 'Income_0_40', 
          'Income_40_60', 'Income_60_80', 'Income_80_120', 'Credit_Limit']]
y = crdt['AUR_Percentage']
X
# Out:
#        Customer_Age  Customer_Gender  Education_D1_Doctorate  \
# 0                45                1                       0
# 1                49                0                       0
# 2                51                1                       0
# 3                40                0                       0
# 4                40                1                       0
# ...             ...              ...                     ...
# 10122            50                1                       0
# 10123            41                1                       0
# 10124            44                0                       0
# 10125            30                1                       0
# 10126            43                0                       0
#
#        Education_D2_PostGraduate  Education_D3_Graduate  Education_D4_College  \
# 0                              0                      0                     0
# 1                              0                      1                     0
# 2                              0                      1                     0
# 3                              0                      0                     0
# 4                              0                      0                     0
# ...                          ...                    ...                   ...
# 10122                          0                      1                     0
# 10123                          0                      0                     0
# 10124                          0                      0                     0
# 10125                          0                      1                     0
# 10126                          0                      1                     0
#
#        Education_D5_HighSchool  Education_D6_Uneducated  Marital_D1_Single  \
# 0                            1                        0                  0
# 1                            0                        0                  1
# 2                            0                        0                  0
# 3                            1                        0                  0
# 4                            0                        1                  0
# ...                        ...                      ...                ...
# 10122                        0                        0                  1
# 10123                        0                        0                  0
# 10124                        1                        0                  0
# 10125                        0                        0                  0
# 10126                        0                        0                  0
#
#        Marital_D2_Married  Marital_D3_Divorced  Income_0_40  Income_40_60  \
# 0                       1                    0            0             0
# 1                       0                    0            1             0
# 2                       1                    0            0             0
# 3                       0                    0            1             0
# 4                       1                    0            0             0
# ...                   ...                  ...          ...           ...
# 10122                   0                    0            0             1
# 10123                   0                    1            0             1
# 10124                   1                    0            1             0
# 10125                   0                    0            0             1
# 10126                   1                    0            1             0
#
#        Income_60_80  Income_80_120  Credit_Limit
# 0                 1              0       12691.0
# 1                 0              0        8256.0
# 2                 0              1        3418.0
# 3                 0              0        3313.0
# 4                 1              0        4716.0
# ...             ...            ...           ...
# 10122             0              0        4003.0
# 10123             0              0        4277.0
# 10124             0              0        5409.0
# 10125             0              0        5281.0
# 10126             0              0       10388.0
#
# [10127 rows x 16 columns]

# %%
crdt.describe()
# Out:
#        Customer_Age  Customer_Gender  Education_D1_Doctorate  \
# count  10127.000000     10127.000000            10127.000000
# mean      46.325960         0.470919                0.044534
# std        8.016814         0.499178                0.206289
# min       26.000000         0.000000                0.000000
# 25%       41.000000         0.000000                0.000000
# 50%       46.000000         0.000000                0.000000
# 75%       52.000000         1.000000                0.000000
# max       73.000000         1.000000                1.000000
#
#        Education_D2_PostGraduate  Education_D3_Graduate  Education_D4_College  \
# count               10127.000000           10127.000000          10127.000000
# mean                    0.050953               0.308877              0.100030
# std                     0.219912               0.462053              0.300054
# min                     0.000000               0.000000              0.000000
# 25%                     0.000000               0.000000              0.000000
# 50%                     0.000000               0.000000              0.000000
# 75%                     0.000000               1.000000              0.000000
# max                     1.000000               1.000000              1.000000
#
#        Education_D5_HighSchool  Education_D6_Uneducated  Marital_D1_Single  \
# count             10127.000000             10127.000000       10127.000000
# mean                  0.198776                 0.146835           0.389355
# std                   0.399098                 0.353959           0.487628
# min                   0.000000                 0.000000           0.000000
# 25%                   0.000000                 0.000000           0.000000
# 50%                   0.000000                 0.000000           0.000000
# 75%                   0.000000                 0.000000           1.000000
# max                   1.000000                 1.000000           1.000000
#
#        Marital_D2_Married  Marital_D3_Divorced   Income_0_40  Income_40_60  \
# count        10127.000000         10127.000000  10127.000000  10127.000000
# mean             0.462822             0.073862      0.351634      0.176755
# std              0.498641             0.261559      0.477504      0.381480
# min              0.000000             0.000000      0.000000      0.000000
# 25%              0.000000             0.000000      0.000000      0.000000
# 50%              0.000000             0.000000      0.000000      0.000000
# 75%              1.000000             0.000000      1.000000      0.000000
# max              1.000000             1.000000      1.000000      1.000000
#
#        Income_60_80  Income_80_120  Credit_Limit  AUR_Percentage
# count  10127.000000   10127.000000  10127.000000    10127.000000
# mean       0.138442       0.151575   8631.953698       27.528093
# std        0.345380       0.358626   9088.776650       27.586794
# min        0.000000       0.000000   1438.300000        0.000000
# 25%        0.000000       0.000000   2555.000000        2.000000
# 50%        0.000000       0.000000   4549.000000       18.000000
# 75%        0.000000       0.000000  11067.500000       50.000000
# max        1.000000       1.000000  34516.000000      100.000000

# %% [markdown]
# ### Ramdom Sampling

# %%
crdtr = crdt.sample(n=1000, replace=False, axis=0)
crdtr
# Out:
#       Customer_Age  Customer_Gender  Education_D1_Doctorate  \
# 9706            53                0                       0
# 6106            54                1                       0
# 963             48                0                       0
# 6834            40                0                       0
# 2772            37                1                       0
# ...            ...              ...                     ...
# 9355            52                0                       0
# 9369            41                1                       0
# 6941            47                1                       0
# 4551            45                1                       0
# 696             57                0                       0
#
#       Education_D2_PostGraduate  Education_D3_Graduate  Education_D4_College  \
# 9706                          0                      0                     0
# 6106                          1                      0                     0
# 963                           0                      0                     1
# 6834                          0                      0                     0
# 2772                          0                      1                     0
# ...                         ...                    ...                   ...
# 9355                          0                      0                     0
# 9369                          0                      0                     0
# 6941                          0                      0                     0
# 4551                          0                      0                     0
# 696                           0                      0                     0
#
#       Education_D5_HighSchool  Education_D6_Uneducated  Marital_D1_Single  \
# 9706                        1                        0                  0
# 6106                        0                        0                  1
# 963                         0                        0                  0
# 6834                        1                        0                  0
# 2772                        0                        0                  1
# ...                       ...                      ...                ...
# 9355                        1                        0                  1
# 9369                        0                        0                  0
# 6941                        0                        1                  0
# 4551                        1                        0                  1
# 696                         1                        0                  0
#
#       Marital_D2_Married  Marital_D3_Divorced  Income_0_40  Income_40_60  \
# 9706                   1                    0            0             0
# 6106                   0                    0            0             0
# 963                    1                    0            1             0
# 6834                   1                    0            1             0
# 2772                   0                    0            0             0
# ...                  ...                  ...          ...           ...
# 9355                   0                    0            1             0
# 9369                   1                    0            0             0
# 6941                   1                    0            0             0
# 4551                   0                    0            1             0
# 696                    1                    0            0             0
#
#       Income_60_80  Income_80_120  Credit_Limit  AUR_Percentage
# 9706             0              0        7469.0              17
# 6106             0              1       34516.0               7
# 963              0              0        4570.0              53
# 6834             0              0        1762.0              70
# 2772             0              0       34516.0               0
# ...            ...            ...           ...             ...
# 9355             0              0        3029.0              75
# 9369             1              0       27945.0               0
# 6941             1              0        6519.0              23
# 4551             0              0        2766.0              72
# 696              0              0        8362.0               0
#
# [1000 rows x 17 columns]

# %%
X = crdtr[['Customer_Age', 'Customer_Gender', 'Education_D1_Doctorate', 
          'Education_D2_PostGraduate', 'Education_D3_Graduate', 
           'Education_D4_College', 'Education_D5_HighSchool', 
           'Education_D6_Uneducated', 'Marital_D1_Single', 
           'Marital_D2_Married', 'Marital_D3_Divorced', 'Income_0_40', 
           'Income_40_60', 'Income_60_80', 'Income_80_120', 'Credit_Limit']]
# X = crdtr[['Customer_Age', 'Credit_Limit']]
y = crdtr['AUR_Percentage']
X
# Out:
#       Customer_Age  Customer_Gender  Education_D1_Doctorate  \
# 9706            53                0                       0
# 6106            54                1                       0
# 963             48                0                       0
# 6834            40                0                       0
# 2772            37                1                       0
# ...            ...              ...                     ...
# 9355            52                0                       0
# 9369            41                1                       0
# 6941            47                1                       0
# 4551            45                1                       0
# 696             57                0                       0
#
#       Education_D2_PostGraduate  Education_D3_Graduate  Education_D4_College  \
# 9706                          0                      0                     0
# 6106                          1                      0                     0
# 963                           0                      0                     1
# 6834                          0                      0                     0
# 2772                          0                      1                     0
# ...                         ...                    ...                   ...
# 9355                          0                      0                     0
# 9369                          0                      0                     0
# 6941                          0                      0                     0
# 4551                          0                      0                     0
# 696                           0                      0                     0
#
#       Education_D5_HighSchool  Education_D6_Uneducated  Marital_D1_Single  \
# 9706                        1                        0                  0
# 6106                        0                        0                  1
# 963                         0                        0                  0
# 6834                        1                        0                  0
# 2772                        0                        0                  1
# ...                       ...                      ...                ...
# 9355                        1                        0                  1
# 9369                        0                        0                  0
# 6941                        0                        1                  0
# 4551                        1                        0                  1
# 696                         1                        0                  0
#
#       Marital_D2_Married  Marital_D3_Divorced  Income_0_40  Income_40_60  \
# 9706                   1                    0            0             0
# 6106                   0                    0            0             0
# 963                    1                    0            1             0
# 6834                   1                    0            1             0
# 2772                   0                    0            0             0
# ...                  ...                  ...          ...           ...
# 9355                   0                    0            1             0
# 9369                   1                    0            0             0
# 6941                   1                    0            0             0
# 4551                   0                    0            1             0
# 696                    1                    0            0             0
#
#       Income_60_80  Income_80_120  Credit_Limit
# 9706             0              0        7469.0
# 6106             0              1       34516.0
# 963              0              0        4570.0
# 6834             0              0        1762.0
# 2772             0              0       34516.0
# ...            ...            ...           ...
# 9355             0              0        3029.0
# 9369             1              0       27945.0
# 6941             1              0        6519.0
# 4551             0              0        2766.0
# 696              0              0        8362.0
#
# [1000 rows x 16 columns]

# %%
y
# Out:
# 9706    17
# 6106     7
# 963     53
# 6834    70
# 2772     0
#         ..
# 9355    75
# 9369     0
# 6941    23
# 4551    72
# 696      0
# Name: AUR_Percentage, Length: 1000, dtype: int64

# %% [markdown]
# ### Testing and Training Data

# %%
X = X.values
y = y.values
X_train, X_test, y_train, t_test = train_test_split(X, y, test_size=.3, 
                                                    random_state=42)
# print(X, y)
print('Shape of Training Data:', X_train.shape)
print('Shape of Testing Data:', X_test.shape)
# Out:
# Shape of Training Data: (700, 16)
# Shape of Testing Data: (300, 16)

# %% [markdown]
# ### Plotting The Decision Margin

# %%
def meshgrid(x, y, h=0.2):
    x_min, x_max = x.min()-1, x.max()+1
    y_min, y_max = y.min()-1, y.max()+1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    return xx, yy

def contours(ax, clf, xx, yy, **params):
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    output = ax.contourf(xx, yy, Z, **params)
    return output

# %% [markdown]
# ### Principle Component Analysis

# %%
## PCA for SVM
pcaSVM = PCA(n_components=2, iterated_power=1)
trainset_reduction = pcaSVM.fit_transform(X_train)
# PCA for SVR
pcaSVR = PCA(n_components=1, iterated_power=1)
X_reduction = pcaSVR.fit_transform(X)

# %%
print(trainset_reduction)
# Out:
# [[ 2.54209133e+04 -6.21222562e+00]
#  [ 4.38791329e+03 -2.35267565e+00]
#  [ 1.30619133e+04  3.70795725e+00]
#  ...
#  [-4.45308673e+03  6.59251136e+00]
#  [ 7.60913262e+02  2.62648884e+00]
#  [-2.26086724e+02  6.17167115e-01]]

# %%
print(X_reduction)
# Out:
# [[-1.28919101e+03]
#  [ 2.57578090e+04]
#  [-4.18819103e+03]
#  [-6.99619102e+03]
#  [ 2.57578090e+04]
#  [-5.17519098e+03]
#  [ 2.57578090e+04]
#  [ 5.83780903e+03]
#  [ 9.28090234e+01]
#  [ 4.97808970e+02]
#  [-4.43919100e+03]
#  [-2.63019100e+03]
#  [ 3.93980901e+03]
#  [ 1.72998090e+04]
#  [ 8.51880902e+03]
#  [ 1.25458090e+04]
#  [-2.48919098e+03]
#  [-7.31989102e+03]
#  [-3.82190967e+02]
#  [-5.51219102e+03]
#  [-6.15119099e+03]
#  [ 6.43980901e+03]
#  [-6.80719102e+03]
#  [ 4.10180899e+03]
#  [-5.66319099e+03]
#  [-7.31989102e+03]
#  [ 2.49528090e+04]
#  [-6.94619101e+03]
#  [ 5.56180903e+03]
#  [-5.68619101e+03]
#  [-2.33519098e+03]
#  [-3.30619103e+03]
#  [-1.12219101e+03]
#  [-7.06319101e+03]
#  [-6.41219100e+03]
#  [-4.05019101e+03]
#  [-6.23119098e+03]
#  [-7.16519100e+03]
#  [-6.04219103e+03]
#  [-6.13019103e+03]
#  [-1.84719099e+03]
#  [ 2.19080901e+03]
#  [-6.48019100e+03]
#  [ 2.38288090e+04]
#  [-5.04919101e+03]
#  [ 2.37958090e+04]
#  [-5.72919103e+03]
#  [ 1.91868090e+04]
#  [-2.23919098e+03]
#  [-5.99219100e+03]
#  [-3.96191013e+02]]

# %% [markdown]
# ### Support Vector Machine

# %% [markdown]
# ###### Linear SVM

# %%
### Linear SVM
linearSvmModel = make_pipeline(StandardScaler(), 
                               SVC(gamma='auto', kernel="linear", 
                                   probability=True, random_state=42, 
                                   verbose=3))

linearSvmModel.fit(trainset_reduction, y_train)
# Out:
# [LibSVM]
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc',
#                  SVC(gamma='auto', kernel='linear', probability=True,
#                      random_state=42, verbose=3))])

# %%
## Prediction & Accuracy
linearPredictionSVM = linearSvmModel.predict(trainset_reduction)
linearAccuracySVM = linearSvmModel.score(trainset_reduction, y_train)
print('The accurary is:', linearAccuracySVM)
# Out:
# The accurary is: 0.24571428571428572

# %%
## Plotting
X0, X1 = trainset_reduction[:, 0], trainset_reduction[:, 1]
xx, yy = meshgrid(X0, X1)
contours(plt, linearSvmModel, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
plt.scatter(X0, X1, c=y_train, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Creditcard Usage Rate Prediction' + '\n' + 
          'Accuracy:%.2f'%linearAccuracySVM)
plt.show()

# %% [markdown]
# ###### RBF SVM

# %%
### RBF SVM
rbfSvmModel = make_pipeline(StandardScaler(), 
                               SVC(gamma='auto', kernel="rbf", 
                                   probability=True, random_state=42, 
                                   verbose=3))

rbfSvmModel.fit(trainset_reduction, y_train)
# Out:
# [LibSVM]
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc',
#                  SVC(gamma='auto', probability=True, random_state=42,
#                      verbose=3))])

# %%
## Prediction & Accuracy
rbfPredictionSVM = rbfSvmModel.predict(trainset_reduction)
rbfAccuracySVM = rbfSvmModel.score(trainset_reduction, y_train)
print('The accurary is:', rbfAccuracySVM)
# Out:
# The accurary is: 0.25

# %%
## Plotting
X0, X1 = trainset_reduction[:, 0], trainset_reduction[:, 1]
xx, yy = meshgrid(X0, X1)
contours(plt, rbfSvmModel, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
plt.scatter(X0, X1, c=y_train, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Creditcard Usage Rate Prediction' + '\n' + 'Accuracy:%.2f'%rbfAccuracySVM)
plt.show()

# %% [markdown]
# ###### Polynomial SVM

# %%
### Polynomial SVM
polySvmModel = make_pipeline(StandardScaler(), 
                               SVC(gamma='auto', kernel="poly", 
                                   probability=True, random_state=42, 
                                   verbose=3))

polySvmModel.fit(trainset_reduction, y_train)
# Out:
# [LibSVM]
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc',
#                  SVC(gamma='auto', kernel='poly', probability=True,
#                      random_state=42, verbose=3))])

# %%
## Prediction & Accuracy
polyPredictionSVM = polySvmModel.predict(trainset_reduction)
polyAccuracySVM = polySvmModel.score(trainset_reduction, y_train)
print('The accurary is:', polyAccuracySVM)
# Out:
# The accurary is: 0.25142857142857145

# %%
## Plotting
X0, X1 = trainset_reduction[:, 0], trainset_reduction[:, 1]
xx, yy = meshgrid(X0, X1)
contours(plt, polySvmModel, xx, yy, cmap=plt.cm.coolwarm, alpha=0.8)
plt.scatter(X0, X1, c=y_train, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Creditcard Usage Rate Prediction' + '\n' + 
          'Accuracy:%.2f'%polyAccuracySVM)
plt.show()

# %% [markdown]
# ### Support Vector Regression

# %% [markdown]
# ###### Linear SVR

# %%
### Linear SVR
linearSvrModel = make_pipeline(StandardScaler(), 
                               SVR(kernel='linear', C=1.0, epsilon=0.2))
linearSvrModel.fit(X_reduction, y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svr', SVR(epsilon=0.2, kernel='linear'))])

# %%
## Model Assessment
predictionSVR = linearSvrModel.predict(X_reduction)
mse = metrics.mean_squared_error(y, predictionSVR)
print('R2 score:', linearSvrModel.score(X_reduction, y))
print('MSE score:', mse)
# Out:
# R2 score: 0.18963060986670333
# MSE score: 578.8402095328454

# %%
## Plotting
plt.scatter(X_reduction, y, s=10, label='Real Data')
plt.scatter(X_reduction, predictionSVR, color='r', s=10, label='Predicted Data')
plt.xlabel('Personal Information')
plt.ylabel('Creditcard Usage Rate')
plt.legend()

# %% [markdown]
# ###### RBF SVR

# %%
### RBF SVR
rbfSvrModel = make_pipeline(StandardScaler(), 
                               SVR(kernel='rbf', C=1.0, epsilon=0.2))
rbfSvrModel.fit(X_reduction, y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svr', SVR(epsilon=0.2))])

# %%
## Model Assessment
rbfPredictionSVR = rbfSvrModel.predict(X_reduction)
mse = metrics.mean_squared_error(y, rbfPredictionSVR)
print('R2 score:', rbfSvrModel.score(X_reduction, y))
print('MSE score:', mse)
# Out:
# R2 score: 0.3051789044605916
# MSE score: 496.305010315995

# %%
## Plotting
plt.scatter(X_reduction, y, s=10, label='Real Data')
plt.scatter(X_reduction, rbfPredictionSVR, color='r', s=10, label='Predicted Data')
plt.xlabel('Personal Information')
plt.ylabel('Creditcard Usage Rate')
plt.legend()

# %% [markdown]
# ###### Polynomial SVR

# %%
### Polynomial SVR
polySvrModel = make_pipeline(StandardScaler(), 
                               SVR(kernel='poly', C=1.0, epsilon=0.2))
polySvrModel.fit(X_reduction, y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svr', SVR(epsilon=0.2, kernel='poly'))])

# %%
## Model Assessment
polyPredictionSVR = polySvrModel.predict(X_reduction)
mse = metrics.mean_squared_error(y, polyPredictionSVR)
print('R2 score:', polySvrModel.score(X_reduction, y))
print('MSE score:', mse)
# Out:
# R2 score: -0.031013452746844417
# MSE score: 736.4444539557451

# %%
## Plotting
plt.scatter(X_reduction, y, s=10, label='Real Data')
plt.scatter(X_reduction, polyPredictionSVR, color='r', s=10, label='Predicted Data')
plt.xlabel('Personal Information')
plt.ylabel('Creditcard Usage Rate')
plt.legend()

# %% [markdown]
# ### Linear Regression

# %%
## Model Assessment of Linear Regression
lineaR = LinearRegression().fit(X_reduction, y)

predictionLine = lineaR.predict(X_reduction)
mse = metrics.mean_squared_error(y, predictionLine)

print('R2 score:', lineaR.score(X_reduction, y))
print('MSE score:', mse)
# Out:
# R2 score: 0.2251531702933245
# MSE score: 553.466735940628

# %%
## Plotting
plt.scatter(X_reduction, y, s=10, label='Real Data')
plt.scatter(X_reduction, predictionLine, color='r', s=10, label='Predicted Data')
plt.xlabel('Personal Information')
plt.ylabel('Creditcard Usage Rate')
plt.legend()

# %% [markdown]
# ### GridSearch CV

# %%
parameters = {'kernel':('linear', 'rbf', 'poly'), 'epsilon':[0.1, 0.01]}

svr = svm.SVR()
reg = GridSearchCV(svr, parameters, verbose=10)

reg.fit(X_reduction, y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5; 1/6] START epsilon=0.1, kernel=linear..................................
# [CV 1/5; 1/6] END ..epsilon=0.1, kernel=linear;, score=-9.600 total time= 5.9min
# [CV 2/5; 1/6] START epsilon=0.1, kernel=linear..................................
# [CV 2/5; 1/6] END .epsilon=0.1, kernel=linear;, score=-23.779 total time= 4.1min
# [CV 3/5; 1/6] START epsilon=0.1, kernel=linear..................................
# [CV 3/5; 1/6] END .epsilon=0.1, kernel=linear;, score=-13.647 total time= 4.2min
# [CV 4/5; 1/6] START epsilon=0.1, kernel=linear..................................
# [CV 4/5; 1/6] END .epsilon=0.1, kernel=linear;, score=-35.013 total time= 5.0min
# [CV 5/5; 1/6] START epsilon=0.1, kernel=linear..................................
# [CV 5/5; 1/6] END .epsilon=0.1, kernel=linear;, score=-12.184 total time= 3.7min
# [CV 1/5; 2/6] START epsilon=0.1, kernel=rbf.....................................
# [CV 1/5; 2/6] END ......epsilon=0.1, kernel=rbf;, score=0.251 total time=   0.0s
# [CV 2/5; 2/6] START epsilon=0.1, kernel=rbf.....................................
# [CV 2/5; 2/6] END ......epsilon=0.1, kernel=rbf;, score=0.364 total time=   0.0s
# [CV 3/5; 2/6] START epsilon=0.1, kernel=rbf.....................................
# [CV 3/5; 2/6] END ......epsilon=0.1, kernel=rbf;, score=0.215 total time=   0.0s
# [CV 4/5; 2/6] START epsilon=0.1, kernel=rbf.....................................
# [CV 4/5; 2/6] END ......epsilon=0.1, kernel=rbf;, score=0.299 total time=   0.0s
# [CV 5/5; 2/6] START epsilon=0.1, kernel=rbf.....................................
# [CV 5/5; 2/6] END ......epsilon=0.1, kernel=rbf;, score=0.344 total time=   0.0s
# [CV 1/5; 3/6] START epsilon=0.1, kernel=poly....................................
# [CV 1/5; 3/6] END ....epsilon=0.1, kernel=poly;, score=-0.009 total time=   0.0s
# [CV 2/5; 3/6] START epsilon=0.1, kernel=poly....................................
# [CV 2/5; 3/6] END ....epsilon=0.1, kernel=poly;, score=-0.147 total time=   0.0s
# [CV 3/5; 3/6] START epsilon=0.1, kernel=poly....................................
# [CV 3/5; 3/6] END ....epsilon=0.1, kernel=poly;, score=-0.031 total time=   0.0s
# [CV 4/5; 3/6] START epsilon=0.1, kernel=poly....................................
# [CV 4/5; 3/6] END .....epsilon=0.1, kernel=poly;, score=0.049 total time=   0.0s
# [CV 5/5; 3/6] START epsilon=0.1, kernel=poly....................................
# [CV 5/5; 3/6] END ....epsilon=0.1, kernel=poly;, score=-0.059 total time=   0.0s
# [CV 1/5; 4/6] START epsilon=0.01, kernel=linear.................................
# [CV 1/5; 4/6] END .epsilon=0.01, kernel=linear;, score=-9.393 total time= 3.4min
# [CV 2/5; 4/6] START epsilon=0.01, kernel=linear.................................
# [CV 2/5; 4/6] END epsilon=0.01, kernel=linear;, score=-23.013 total time= 5.1min
# [CV 3/5; 4/6] START epsilon=0.01, kernel=linear.................................
# [CV 3/5; 4/6] END epsilon=0.01, kernel=linear;, score=-13.658 total time= 4.3min
# [CV 4/5; 4/6] START epsilon=0.01, kernel=linear.................................
# [CV 4/5; 4/6] END epsilon=0.01, kernel=linear;, score=-35.002 total time= 3.3min
# [CV 5/5; 4/6] START epsilon=0.01, kernel=linear.................................
# [CV 5/5; 4/6] END epsilon=0.01, kernel=linear;, score=-12.253 total time= 3.0min
# [CV 1/5; 5/6] START epsilon=0.01, kernel=rbf....................................
# [CV 1/5; 5/6] END .....epsilon=0.01, kernel=rbf;, score=0.251 total time=   0.0s
# [CV 2/5; 5/6] START epsilon=0.01, kernel=rbf....................................
# [CV 2/5; 5/6] END .....epsilon=0.01, kernel=rbf;, score=0.364 total time=   0.0s
# [CV 3/5; 5/6] START epsilon=0.01, kernel=rbf....................................
# [CV 3/5; 5/6] END .....epsilon=0.01, kernel=rbf;, score=0.215 total time=   0.0s
# [CV 4/5; 5/6] START epsilon=0.01, kernel=rbf....................................
# [CV 4/5; 5/6] END .....epsilon=0.01, kernel=rbf;, score=0.299 total time=   0.0s
# [CV 5/5; 5/6] START epsilon=0.01, kernel=rbf....................................
# [CV 5/5; 5/6] END .....epsilon=0.01, kernel=rbf;, score=0.344 total time=   0.0s
# [CV 1/5; 6/6] START epsilon=0.01, kernel=poly...................................
# [CV 1/5; 6/6] END ...epsilon=0.01, kernel=poly;, score=-0.011 total time=   0.0s
# [CV 2/5; 6/6] START epsilon=0.01, kernel=poly...................................
# [CV 2/5; 6/6] END ...epsilon=0.01, kernel=poly;, score=-0.146 total time=   0.0s
# [CV 3/5; 6/6] START epsilon=0.01, kernel=poly...................................
# [CV 3/5; 6/6] END ...epsilon=0.01, kernel=poly;, score=-0.032 total time=   0.0s
# [CV 4/5; 6/6] START epsilon=0.01, kernel=poly...................................
# [CV 4/5; 6/6] END ....epsilon=0.01, kernel=poly;, score=0.050 total time=   0.0s
# [CV 5/5; 6/6] START epsilon=0.01, kernel=poly...................................
# [CV 5/5; 6/6] END ...epsilon=0.01, kernel=poly;, score=-0.060 total time=   0.0s
# GridSearchCV(estimator=SVR(),
#              param_grid={'epsilon': [0.1, 0.01],
#                          'kernel': ('linear', 'rbf', 'poly')},
#              verbose=10)

# %%
reg.score(X_reduction, y)
# Out:
# 0.30484732357063216

# %%
